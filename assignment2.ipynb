# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("profiles.csv")

# %%
df.head(1)
# Out:
#    age       body_type               diet    drinks  drugs  \
# 0   22  a little extra  strictly anything  socially  never
#
#                        education  \
# 0  working on college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
#
#                                               essay2  \
# 0  making people laugh.<br />\nranting about a go...
#
#                                               essay3  ...  \
# 0  the way i look. i am a six foot half asian, ha...  ...
#
#                           location  \
# 0  south san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
#
#                         pets                               religion sex  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'essay0',
#        'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7',
#        'essay8', 'essay9', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'orientation', 'pets',
#        'religion', 'sex', 'sign', 'smokes', 'speaks', 'status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age              int64
# body_type       object
# diet            object
# drinks          object
# drugs           object
# education       object
# essay0          object
# essay1          object
# essay2          object
# essay3          object
# essay4          object
# essay5          object
# essay6          object
# essay7          object
# essay8          object
# essay9          object
# ethnicity       object
# height         float64
# income           int64
# job             object
# last_online     object
# location        object
# offspring       object
# orientation     object
# pets            object
# religion        object
# sex             object
# sign            object
# smokes          object
# speaks          object
# status          object
# dtype: object

# %%
#df['ethnicity'].value_counts()

# %%
df['offspring'].value_counts()
# Out:
# doesn&rsquo;t have kids                                7560
# doesn&rsquo;t have kids, but might want them           3875
# doesn&rsquo;t have kids, but wants them                3565
# doesn&rsquo;t want kids                                2927
# has kids                                               1883
# has a kid                                              1881
# doesn&rsquo;t have kids, and doesn&rsquo;t want any    1132
# has kids, but doesn&rsquo;t want more                   442
# has a kid, but doesn&rsquo;t want more                  275
# has a kid, and might want more                          231
# wants kids                                              225
# might want kids                                         182
# has kids, and might want more                           115
# has a kid, and wants more                                71
# has kids, and wants more                                 21
# Name: offspring, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# m    35829
# f    24117
# Name: sex, dtype: int64

# %%
df['orientation'].value_counts()
# Out:
# straight    51606
# gay          5573
# bisexual     2767
# Name: orientation, dtype: int64

# %%
len(df.loc[(df['orientation'] == 'straight') & (df['sex'] == 'm')])
# Out:
# 31073

# %%
len(df.loc[(df['orientation'] == 'straight') & (df['sex'] == 'f')])
# Out:
# 20533

# %%
len(df.loc[(df['orientation'] == 'gay') & (df['sex'] == 'm')])
# Out:
# 3985

# %%
len(df.loc[(df['orientation'] == 'gay') & (df['sex'] == 'f')])
# Out:
# 1588

# %%
len(df.loc[(df['orientation'] == 'bisexual') & (df['sex'] == 'm')])
# Out:
# 771

# %%
len(df.loc[(df['orientation'] == 'bisexual') & (df['sex'] == 'f')])
# Out:
# 1996

# %%
data = {'1': ["straight", "male", 31073], '2': ['straight', 'female', 20533], \
       '3': ['gay', 'male', 3985], '4': ['gay', 'female', 1588], '5': ['bisexual', 'male', 771], \
       '6': ['bisexual', 'female', 1996]}

data = pd.DataFrame.from_dict(data, orient='index')

# %%
data.columns = ['orientation', 'sex', 'count']
data
# Out:
#   orientation     sex  count
# 1    straight    male  31073
# 2    straight  female  20533
# 3         gay    male   3985
# 4         gay  female   1588
# 5    bisexual    male    771
# 6    bisexual  female   1996

# %%
#df['sign']

# %%
import seaborn as sns
#sns.set_theme(style="ticks", palette="pastel")

# %%
g = sns.catplot(x='orientation', y = 'count',kind="bar",
            hue='sex', palette=["b", "g"],
            data=data)#.set_title('Count of Sexual Orientation by Gender')
axes = g.axes.flatten()
axes[0].set_title('Count of Sexual Orientation by Gender')
# Out:
# Text(0.5, 1, 'Count of Sexual Orientation by Gender')

# %%
df.describe()
# Out:
#                 age        height          income
# count  59946.000000  59943.000000    59946.000000
# mean      32.340290     68.295281    20033.222534
# std        9.452779      3.994803    97346.192104
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max      110.000000     95.000000  1000000.000000

# %%
dfwomen = df.loc[df['sex'] == 'f']
dfmen = df.loc[df['sex'] == 'm']

# %%
dfwomen.describe()
# Out:
#                 age        height          income
# count  24117.000000  24116.000000    24117.000000
# mean      32.818220     65.103873    11181.697392
# std       10.025385      2.926502    74149.778856
# min       18.000000      4.000000       -1.000000
# 25%       26.000000     63.000000       -1.000000
# 50%       30.000000     65.000000       -1.000000
# 75%       37.000000     67.000000       -1.000000
# max      110.000000     95.000000  1000000.000000

# %%
dfmen.describe()
# Out:
#                 age        height          income
# count  35829.000000  35827.000000    35829.000000
# mean      32.018588     70.443492    25991.307656
# std        9.032881      3.076521   109845.249284
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     68.000000       -1.000000
# 50%       30.000000     70.000000       -1.000000
# 75%       36.000000     72.000000       -1.000000
# max      109.000000     95.000000  1000000.000000

# %%
def replacestr(x):
    try:
        str(x).replace("&rsquo;", "hi")
        return x
    except:
        return x

# %%
df['offspring'] = df['offspring'].str.replace("&rsquo;", "'")

# %%
sns.set(rc={'figure.figsize':(20,10)})

plt = sns.countplot(x = "offspring", data = df,palette=["b", "g"], hue = 'sex')

plt.set_xticklabels(plt.get_xticklabels(),rotation=80)
plt.set_title('Count of Offspring Preferences by Gender')
#plt.setp(ax.get_legend().get_texts(), fontsize='22') 
#plt.rcParams['title_fontsize'] = 50
# Out:
# Text(0.5, 1.0, 'Count of Offspring Preferences by Gender')

# %%
df.columns
# Out:
# Index(['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'essay0',
#        'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7',
#        'essay8', 'essay9', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'orientation', 'pets',
#        'religion', 'sex', 'sign', 'smokes', 'speaks', 'status'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(15,7)})
sns.boxplot(x='height', y = 'sex', data = df, palette=["b", "g"])

# %%
sns.set(rc={'figure.figsize':(15,7)})
sns.boxplot(x='income', y = 'sex', data = df, palette=["b", "g"])

# %%
sns.set(rc={'figure.figsize':(20,10)})

plt = sns.countplot(x = "pets", data = df, hue = 'sex', palette=["b", "g"])

plt.set_xticklabels(plt.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'likes dogs and likes cats'),
#  Text(0, 0, 'has cats'),
#  Text(0, 0, 'likes cats'),
#  Text(0, 0, 'has dogs and likes cats'),
#  Text(0, 0, 'likes dogs and has cats'),
#  Text(0, 0, 'likes dogs and dislikes cats'),
#  Text(0, 0, 'has dogs'),
#  Text(0, 0, 'has dogs and dislikes cats'),
#  Text(0, 0, 'likes dogs'),
#  Text(0, 0, 'has dogs and has cats'),
#  Text(0, 0, 'dislikes dogs and has cats'),
#  Text(0, 0, 'dislikes dogs and dislikes cats'),
#  Text(0, 0, 'dislikes cats'),
#  Text(0, 0, 'dislikes dogs and likes cats'),
#  Text(0, 0, 'dislikes dogs')]

# %%
df['sign'] = df['sign'].str.replace("&rsquo;", "'")
sns.set(rc={'figure.figsize':(20,10)})

plt = sns.countplot(x = "sign", data = df, hue = 'sex')

plt.set_xticklabels(plt.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'gemini'),
#  Text(0, 0, 'cancer'),
#  Text(0, 0, "pisces but it doesn't matter"),
#  Text(0, 0, 'pisces'),
#  Text(0, 0, 'aquarius'),
#  Text(0, 0, 'taurus'),
#  Text(0, 0, 'virgo'),
#  Text(0, 0, 'sagittarius'),
#  Text(0, 0, "gemini but it doesn't matter"),
#  Text(0, 0, "cancer but it doesn't matter"),
#  Text(0, 0, "leo but it doesn't matter"),
#  Text(0, 0, "aquarius but it doesn't matter"),
#  Text(0, 0, "aries and it's fun to think about"),
#  Text(0, 0, "libra but it doesn't matter"),
#  Text(0, 0, "pisces and it's fun to think about"),
#  Text(0, 0, 'libra'),
#  Text(0, 0, "taurus but it doesn't matter"),
#  Text(0, 0, "sagittarius but it doesn't matter"),
#  Text(0, 0, 'scorpio and it matters a lot'),
#  Text(0, 0, "gemini and it's fun to think about"),
#  Text(0, 0, "leo and it's fun to think about"),
#  Text(0, 0, "cancer and it's fun to think about"),
#  Text(0, 0, "libra and it's fun to think about"),
#  Text(0, 0, "aquarius and it's fun to think about"),
# ...

# %%
df.isna().sum()
# Out:
# age                0
# body_type       5296
# diet           24395
# drinks          2985
# drugs          14080
# education       6628
# essay0          5488
# essay1          7572
# essay2          9638
# essay3         11476
# essay4         10537
# essay5         10850
# essay6         13771
# essay7         12451
# essay8         19225
# essay9         12603
# ethnicity       5680
# height             3
# income             0
# job             8198
# last_online        0
# location           0
# offspring      35561
# orientation        0
# pets           19921
# religion       20226
# sex                0
# sign           11056
# smokes          5512
# speaks            50
# status             0
# dtype: int64

# %%
def signs_helper(x):
    try: 
        if "it doesn't matter" in x:
            return "doesn't matter"
        elif "it matters a lot" in x:
            return "matters"
        elif "fun" in x:
            return "fun to think about"
        else:
            return "N/A"
    except:
        return "N/A"

# %%
df['signmod'] = df['sign'].apply(signs_helper)

# %%
sns.set(rc={'figure.figsize':(20,10)})

plt = sns.countplot(x = "signmod", data = df, hue = 'sex', palette=["b", "g"])

plt.set_xticklabels(plt.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'N/A'),
#  Text(0, 0, "doesn't matter"),
#  Text(0, 0, 'fun to think about'),
#  Text(0, 0, 'matters')]

# %%
#df['essay1']
